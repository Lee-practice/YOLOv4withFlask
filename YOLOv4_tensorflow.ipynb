# %% [markdown]
# * darknet 가중치 파일을 tensorflow를 위한 것으로 변경하기 (tf)

# %%
#tensorflow 버전 변경
# !pip uninstall tensorflow

# %%
# !pip install tensorflow==2.3.0rc0

# %%
#tensorflow 버전 확인
import tensorflow as tf
print(tf.__version__)

# %%
#변환하는 데에 필요한 프로젝트
# !git clone https://github.com/hunglc007/tensorflow-yolov4-tflite

# %%
#드라이브 연동
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#weights 파일과 names 파일 이동
#이 과정 수행 후, /content/tensorflow-yolov4-tflite/core/config.py 파일에서 coco.names 부분을 custom.names로 변경
# !cp /content/gdrive/MyDrive/졸프/yolov4_result_code/ver4/backup/yolov4-custom_best.weights /content/tensorflow-yolov4-tflite/data
# !cp /content/gdrive/MyDrive/졸프/yolov4_result_code/ver4/custom.names /content/tensorflow-yolov4-tflite/data/classes

# %%
# 가중치 파일을 tensorflow를 위한 것으로 변환
# %cd ./tensorflow-yolov4-tflite/
# !python save_model.py --weights ./data/yolov4-custom_best.weights --output ./checkpoints/yolov4-416 --input_size 416 --model yolov4

# %%
# 가중치 파일을 tflite로 변환
# %cd ./tensorflow-yolov4-tflite/
# !python save_model.py --weights ./data/yolov4-custom_best.weights --output ./checkpoints/yolov4-416-tflite --input_size 416 --model yolov4 --framework tflite
# !python convert_tflite.py --weights ./checkpoints/yolov4-416-tflite --output ./checkpoints/yolov4-416.tflite

# %%
# !zip -r model.zip /content/tensorflow-yolov4-tflite

# %%
# !cp /content/tensorflow-yolov4-tflite/model_tflite.zip /content/gdrive/MyDrive/캡스톤자료/
